# %%
# !pip install scrapy

# %%
import scrapy
import pandas

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/PDV/scrapy/"
# Out:
# /content/drive/MyDrive/Colab Notebooks/PDV/scrapy

# %%
# !scrapy startproject scrapy_arxiv_org

# %%
# %cd scrapy_arxiv_org

# %%
# !scrapy crawl basic
